# %% [markdown]
# <a href="https://colab.research.google.com/github/mercedesricci01-svg/Trackeo-METOP/blob/main/CodigoTPFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git init
# Out:
#   File "/tmp/ipython-input-2830201818.py", line 1
#     git init
#         ^
# SyntaxError: invalid syntax

# %%
# !git remote -v

# %%
# !git remote add origin https://github.com/mercedesricci01-svg/Trackeo-METOP.git

# %%
git checkout main
# Out:
#   File "/tmp/ipython-input-4208870776.py", line 1
#     git checkout main
#         ^
# SyntaxError: invalid syntax

# %%
#llamar a librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
